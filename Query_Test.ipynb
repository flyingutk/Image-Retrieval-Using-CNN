# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Relative location of drive to DIP project folder
drive_loc='/content/gdrive/My Drive/DIP/'

# %%
import numpy as np
import cv2
import keras
import random as rand
from keras import backend as K
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.models import Sequential
from keras.models import Model,load_model
from keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# Load MNIST dataset
(x_train,y_train), (x_test,y_test) = mnist.load_data()

# %%
img_rows, img_cols = 28, 28
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
model = load_model(drive_loc + 'model.h5')

# %%
encoder_model = Model(inputs=model.input,outputs=model.get_layer('encoder').output)

# %%
# Compute features for training dataset
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
learned_codes = encoder_model.predict(x_train)
# Reshaping to convert encoded rep of shape: (number_of_images,4,4,8) to (number_of_images,4*4*8)
learned_codes = learned_codes.reshape(learned_codes.shape[0], learned_codes.shape[1] * learned_codes.shape[2] * learned_codes.shape[3])

# Compute features for query/test images
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
test_codes = encoder_model.predict(x_test)
# Reshaping to convert encoded rep of shape: (number_of_images,4,4,8) to (number_of_images,4*4*8)
test_codes = test_codes.reshape(test_codes.shape[0], test_codes.shape[1] * test_codes.shape[2] * test_codes.shape[3])

# %%
from google.colab.patches import cv2_imshow

image_name = '2.png'
n_retreivals = 1000

A = cv2.imread(image_name,cv2.IMREAD_GRAYSCALE)
# A = A.reshape((28,28))
print('Test image:')
cv2_imshow(A)

print('\n#############\n')

A = A.reshape(1,28,28,1)
A = A/255
Features = encoder_model.predict(A)
Features = Features.reshape(128)

distances = []
for i in range(len(learned_codes)):
  distance = np.linalg.norm(learned_codes[i] - Features)
  distances.append((distance,i))
D = sorted(distances)
D = D[:n_retreivals]

for i in range(len(D)):
  A = x_train[D[i][1]]*255
  A = A.astype('int')
  A = A.reshape((28,28))
  print('Retreived image #' + str(i+1))
  cv2_imshow(A)
  print('\n#############\n')
# Out:
# Test image:
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF92901940>
# #############
#
# Retreived image #1
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF929019B0>
# #############
#
# Retreived image #2
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF92901940>
# #############
#
# Retreived image #3
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #4
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #5
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #6
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #7
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #8
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #9
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #10
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #11
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #12
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #13
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #14
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #15
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #16
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #17
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #18
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #19
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #20
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #21
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #22
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #23
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #24
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #25
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #26
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #27
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #28
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #29
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #30
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #31
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #32
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #33
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #34
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #35
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #36
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #37
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #38
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #39
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #40
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #41
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #42
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #43
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #44
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #45
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #46
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #47
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #48
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #49
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #50
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #51
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #52
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #53
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #54
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #55
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #56
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #57
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #58
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #59
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #60
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #61
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #62
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #63
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #64
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #65
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #66
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #67
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #68
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #69
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #70
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #71
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #72
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #73
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #74
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #75
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #76
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #77
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #78
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #79
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #80
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #81
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #82
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #83
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #84
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #85
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #86
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #87
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #88
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #89
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #90
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #91
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #92
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #93
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #94
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #95
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #96
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #97
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #98
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #99
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #100
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #101
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #102
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #103
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #104
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #105
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #106
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #107
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #108
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #109
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #110
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #111
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #112
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #113
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image #114
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCF931ED588>
# #############
#
# Retreived image #115
# <PIL.Image.Image image mode=L size=28x28 at 0x7FCFC0A8E860>
# #############
#
# Retreived image