# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Relative location of drive to DIP project folder
drive_loc='/content/gdrive/My Drive/DIP/'

# %%
import numpy as np
import cv2
import keras
import random as rand
from keras import backend as K
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.models import Sequential
from keras.models import Model,load_model
from keras.datasets import mnist
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-45eb154645f0> in <module>()
#       1 import numpy as np
#       2 import cv2
# ----> 3 import keras
#       4 import random as rand
#       5 from keras import backend as K
#
# /usr/local/lib/python3.6/dist-packages/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py in <module>()
#      87 elif _BACKEND == 'tensorflow':
#      88     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 89     from .tensorflow_backend import *
#      90 else:
#      91     # Try and load external backend.
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/__init__.py in <module>()
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25
#      26 from tensorflow._api.v1 import app
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/__init__.py in <module>()
#      94 from tensorflow.python.ops.losses import losses
#      95 from tensorflow.python.ops.signal import signal
# ---> 96 from tensorflow.python.profiler import profiler
#      97 from tensorflow.python.saved_model import saved_model
#      98 from tensorflow.python.summary import summary
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/profiler.py in <module>()
#      25 from tensorflow.core.profiler.tfprof_output_pb2 import MultiGraphNodeProto
#      26
# ---> 27 from tensorflow.python.profiler.model_analyzer import advise
#      28 from tensorflow.python.profiler.model_analyzer import profile
#      29 from tensorflow.python.profiler.model_analyzer import Profiler
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/model_analyzer.py in <module>()
#      32 from tensorflow.python.framework import errors
#      33 from tensorflow.python.framework import ops
# ---> 34 from tensorflow.python.profiler import option_builder
#      35 from tensorflow.python.profiler import tfprof_logger
#      36 from tensorflow.python.util.tf_export import tf_export
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/option_builder.py in <module>()
#      20 import copy
#      21
# ---> 22 from tensorflow.python.profiler import tfprof_logger
#      23 from tensorflow.python.util.tf_export import tf_export
#      24
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/tfprof_logger.py in <module>()
#      30 from tensorflow.python.framework import tensor_shape
#      31 from tensorflow.python.platform import gfile
# ---> 32 from tensorflow.python.profiler.internal import flops_registry  # pylint: disable=unused-import
#      33 from tensorflow.python.util.tf_export import tf_export
#      34
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/internal/flops_registry.py in <module>()
#      69
#      70
# ---> 71 @ops.RegisterStatistics("Reciprocal", "flops")
#      72 def _reciprocal_flops(graph, node):
#      73   """Compute flops for Reciprocal operation."""
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in __call__(self, f)
#    2723   def __call__(self, f):
#    2724     """Registers "f" as the statistics function for "op_type"."""
# -> 2725     _stats_registry.register(f, self._op_type + "," + self._statistic_type)
#    2726     return f
#    2727
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/registry.py in register(self, candidate, name)
#      59       raise KeyError("Registering two %s with name '%s'! "
#      60                      "(Previous registration was in %s %s:%d)" %
# ---> 61                      (self._name, name, function_name, filename, line_number))
#      62
#      63     logging.vlog(1, "Registering %s (%s) in %s.", name, candidate, self._name)
#
# KeyError: "Registering two statistical functions with name 'Reciprocal,flops'! (Previous registration was in <module> /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16)"

# %%
# Load MNIST dataset
(x_train,y_train), (x_test,y_test) = mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-193af9a3a93b> in <module>()
# ----> 1 (x_train,y_train), (x_test,y_test) = mnist.load_data()
#
# NameError: name 'mnist' is not defined

# %%
img_rows, img_cols = 28, 28
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
model = load_model(drive_loc + 'model.h5')

# %%
encoder_model = Model(inputs=model.input,outputs=model.get_layer('encoder').output)

# %%
# Compute features for training dataset
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
learned_codes = encoder_model.predict(x_train)
# Reshaping to convert encoded rep of shape: (number_of_images,4,4,8) to (number_of_images,4*4*8)
learned_codes = learned_codes.reshape(learned_codes.shape[0], learned_codes.shape[1] * learned_codes.shape[2] * learned_codes.shape[3])

# Compute features for query/test images
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
test_codes = encoder_model.predict(x_test)
# Reshaping to convert encoded rep of shape: (number_of_images,4,4,8) to (number_of_images,4*4*8)
test_codes = test_codes.reshape(test_codes.shape[0], test_codes.shape[1] * test_codes.shape[2] * test_codes.shape[3])

# %%
from google.colab.patches import cv2_imshow


n_retreivals = 100

index = rand.randint(0,len(x_test))
A = x_test[index,:,:,:]*255
A = A.astype('int')
A = A.reshape((28,28))
print('Test image:')
cv2_imshow(A)

print('\n#############\n')

distances = []
for i in range(len(learned_codes)):
  distance = np.linalg.norm(learned_codes[i] - test_codes[index])
  distances.append((distance,i))

D = sorted(distances)
D = D[:n_retreivals]

for i in range(len(D)):
  A = x_train[D[i][1]]*255
  A = A.astype('int')
  A = A.reshape((28,28))
  print('Retreived image #' + str(i+1))
  cv2_imshow(A)
  print('\n#############\n')
# Out:
# Test image:
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BDD8>
# #############
#
# Retreived image #1
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BE80>
# #############
#
# Retreived image #2
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BE10>
# #############
#
# Retreived image #3
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEB8>
# #############
#
# Retreived image #4
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #5
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #6
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #7
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #8
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BE48>
# #############
#
# Retreived image #9
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #10
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BE48>
# #############
#
# Retreived image #11
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #12
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #13
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BE10>
# #############
#
# Retreived image #14
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #15
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #16
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #17
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #18
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #19
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #20
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #21
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #22
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #23
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #24
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #25
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #26
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #27
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #28
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #29
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #30
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #31
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #32
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #33
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #34
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #35
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #36
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #37
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #38
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #39
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #40
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #41
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #42
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #43
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #44
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #45
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #46
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #47
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #48
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #49
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #50
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #51
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #52
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #53
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #54
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #55
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #56
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #57
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #58
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #59
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #60
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #61
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #62
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #63
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #64
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEB8>
# #############
#
# Retreived image #65
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #66
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #67
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #68
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #69
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #70
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #71
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #72
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #73
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #74
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #75
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #76
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #77
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #78
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #79
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #80
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #81
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #82
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEF0>
# #############
#
# Retreived image #83
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #84
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEB8>
# #############
#
# Retreived image #85
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #86
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BEB8>
# #############
#
# Retreived image #87
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BFD0>
# #############
#
# Retreived image #88
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #89
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #90
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #91
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #92
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #93
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #94
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #95
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #96
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #97
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #98
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############
#
# Retreived image #99
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF28>
# #############
#
# Retreived image #100
# <PIL.Image.Image image mode=L size=28x28 at 0x7F275D70BF98>
# #############

# %%
# Out:
# [(801.5343, 33365),
#  (1010.3184, 41387),
#  (1045.3016, 48564),
#  (1048.88, 17495),
#  (1174.4126, 43837),
#  (1211.2172, 38675),
#  (1217.002, 24275),
#  (1221.3418, 41462),
#  (1236.8695, 49012),
#  (1240.2546, 24403)]

# %%
learned_codes = encoder_model.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-11c77784a98e> in <module>()
# ----> 1 learned_codes = encoder_model.predict(x_train)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
